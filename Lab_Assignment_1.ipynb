# %%
import pandas as pd

# Define the file path
file_path = r"C:\Users\DELL\Downloads\archive (1)\Dataset_Generator_for_DTDC.csv"

# Load the dataset
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
df.head()
# Out:
#        Origin  Destination                              Pouch No        Date  \
# 0      Nagpur   Jamshedpur  55e275ad-8da9-49c9-986c-93134fef2c19  2025-06-25
# 1      Jaipur        Vizag  7fab4175-11b2-4090-a0ed-4571ccd68878  2025-06-27
# 2     Lucknow  Bhubaneswar  5231428d-b524-433e-8043-45c7e39a94aa  2025-06-27
# 3  Coimbatore       Mumbai  2f556b38-298d-4e8c-9310-4e6a3a5fbe61  2025-06-11
# 4      Meerut   Vijayawada  c3154041-34eb-435e-94d8-0900e6a9ed01  2025-07-01
#
#       Sender's Name  Sender Phone  \
# 0    Megha Majumdar    6137840452
# 1       Nanda-Saraf      52907142
# 2    Contractor LLC    5081512738
# 3      Krishna Hans    1518559754
# 4  Kuruvilla-Tiwari    1666398391
#
#                                       Sender Address Sender City  \
# 0  H.No. 425 Varughese Chowk, Above Shop, Nagpur,...      Nagpur
# 1  48/880, Tripathi, Above Shop, Jaipur, Rajastha...      Jaipur
# 2  257, Kulkarni Path, Above Shop, Lucknow, Uttar...     Lucknow
# ...

# %%
import matplotlib.pyplot as plt

# Scatter plot to show relationship between 'Tariff' and 'Total Amount'
plt.figure(figsize=(10, 6))
plt.scatter(df['Tariff'], df['Total Amount'])
plt.title('Scatter Plot: Tariff vs Total Amount')
plt.xlabel('Tariff')
plt.ylabel('Total Amount')
plt.show()

# %%
# Bar chart for 'Mode of Payment'
df['Mode of Payment'].value_counts().plot(kind='bar', figsize=(10, 6))
plt.title('Bar Chart: Mode of Payment')
plt.xlabel('Mode of Payment')
plt.ylabel('Count')
plt.show()

# %%
# Histogram for 'Tariff'
df['Tariff'].hist(bins=30, figsize=(10, 6))
plt.title('Histogram: Distribution of Tariff')
plt.xlabel('Tariff')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot for 'Tariff'
plt.figure(figsize=(10, 6))
df.boxplot(column='Tariff')
plt.title('Box Plot: Tariff')
plt.show()

# %%
# Pie chart for 'Nature of Consignment'
df['Nature of Consignment'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8))
plt.title('Pie Chart: Nature of Consignment')
plt.ylabel('')
plt.show()

# %%
# Check for missing values in the 'Tariff' column
df['Tariff'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Tariff'] = df['Tariff'].fillna(df['Tariff'].mean())

# %%
# Check the data type of the 'Tariff' column
df['Tariff'].dtype
# Out:
# dtype('float64')

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Scale the 'Tariff' column
df['Tariff_scaled'] = scaler.fit_transform(df[['Tariff']])

# Display the dataset with scaled 'Tariff'
df.head()
# Out:
#        Origin  Destination                              Pouch No        Date  \
# 0      Nagpur   Jamshedpur  55e275ad-8da9-49c9-986c-93134fef2c19  2025-06-25
# 1      Jaipur        Vizag  7fab4175-11b2-4090-a0ed-4571ccd68878  2025-06-27
# 2     Lucknow  Bhubaneswar  5231428d-b524-433e-8043-45c7e39a94aa  2025-06-27
# 3  Coimbatore       Mumbai  2f556b38-298d-4e8c-9310-4e6a3a5fbe61  2025-06-11
# 4      Meerut   Vijayawada  c3154041-34eb-435e-94d8-0900e6a9ed01  2025-07-01
#
#       Sender's Name  Sender Phone  \
# 0    Megha Majumdar    6137840452
# 1       Nanda-Saraf      52907142
# 2    Contractor LLC    5081512738
# 3      Krishna Hans    1518559754
# 4  Kuruvilla-Tiwari    1666398391
#
#                                       Sender Address Sender City  \
# 0  H.No. 425 Varughese Chowk, Above Shop, Nagpur,...      Nagpur
# 1  48/880, Tripathi, Above Shop, Jaipur, Rajastha...      Jaipur
# 2  257, Kulkarni Path, Above Shop, Lucknow, Uttar...     Lucknow
# ...

# %%
# General info and summary statistics
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49639 entries, 0 to 49638
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Origin                 49639 non-null  object
#  1   Destination            49639 non-null  object
#  2   Pouch No               49639 non-null  object
#  3   Date                   49639 non-null  object
#  4   Sender's Name          49639 non-null  object
#  5   Sender Phone           49639 non-null  int64
#  6   Sender Address         49639 non-null  object
#  7   Sender City            49639 non-null  object
#  8   Sender State           49639 non-null  object
#  9   Sender Pincode         49639 non-null  int64
#  10  Sender GSTIN           26778 non-null  object
#  11  Total Pieces           49639 non-null  int64
#  12  Actual Wt              49639 non-null  float64
#  13  Volumetric Wt          49639 non-null  float64
# ...

# %%
# Calculate central tendency measures for 'Tariff'
min_value = df['Tariff'].min()
max_value = df['Tariff'].max()
mean_value = df['Tariff'].mean()
median_value = df['Tariff'].median()
mode_value = df['Tariff'].mode()[0]

print(f"Min: {min_value}, Max: {max_value}, Mean: {mean_value}, Median: {median_value}, Mode: {mode_value}")
# Out:
# Min: 19.9, Max: 1372.9, Mean: 440.8540792522009, Median: 409.98, Mode: 136.62

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile) for 'Tariff'
Q1 = df['Tariff'].quantile(0.25)
Q3 = df['Tariff'].quantile(0.75)

# Calculate the IQR (Interquartile Range)
IQR_value = Q3 - Q1

# Now you can calculate other measures like Range, Variance, etc.
min_value = df['Tariff'].min()
max_value = df['Tariff'].max()
range_value = max_value - min_value
variance = df['Tariff'].var()
std_dev = df['Tariff'].std()

# Display the results
print(f"Range: {range_value}, Variance: {variance}, Standard Deviation: {std_dev}, IQR: {IQR_value}")
# Out:
# Range: 1353.0, Variance: 59140.51299515073, Standard Deviation: 243.1882254451287, IQR: 316.53

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix on the numeric columns
correlation_matrix = numeric_df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                   Sender Phone  Sender Pincode  Total Pieces  Actual Wt  \
# Sender Phone          1.000000        0.007200     -0.004477   0.005895
# Sender Pincode        0.007200        1.000000      0.004804  -0.003910
# Total Pieces         -0.004477        0.004804      1.000000  -0.000839
# Actual Wt             0.005895       -0.003910     -0.000839   1.000000
# Volumetric Wt         0.004987       -0.002818      0.001009   0.970770
# Chargeable Wt         0.004987       -0.002818      0.001009   0.970770
# Recipient Phone      -0.003747        0.006356      0.001086   0.003537
# Receiver Pincode     -0.002478       -0.005215     -0.008290  -0.002382
# Tariff                0.002389       -0.004703      0.001112   0.797141
# VAS Charges          -0.002375        0.003997     -0.004873   0.007113
# Total Amount          0.001883       -0.003838      0.000149   0.782742
# Tariff_scaled         0.002389       -0.004703      0.001112   0.797141
#
# ...
